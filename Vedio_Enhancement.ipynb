# %%
# %tensorflow_version 2.x
# This is very important version to load weights other wise it will give error
# !pip install tensorflow==2.2.1
# !pip install q keras==2.3.1
# Out:
# Cloning into 'super-resolution'...
# remote: Enumerating objects: 405, done.
# remote: Counting objects: 100% (20/20), done.
# remote: Compressing objects: 100% (12/12), done.
# remote: Total 405 (delta 9), reused 19 (delta 8), pack-reused 385
# Receiving objects: 100% (405/405), 54.27 MiB | 30.17 MiB/s, done.
# Resolving deltas: 100% (209/209), done.

# %%
# !git clone https://github.com/krasserm/super-resolution   #Cloning a Pretrained Model

# %%
## connecting to the google drive

from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
cd /content/drive/MyDrive/major_project_cv/super-resolution/
# Out:
# /content/drive/MyDrive/major_project_cv/super-resolution

# %%
# !tar xvfz /content/weights-srgan.tar.gz

# %%
# Importing all necessary libraries 
import timeit
import cv2 
import os
import numpy as np
from model import resolve_single
from utils import load_image, plot_sample
from model.srgan import generator


# Read the video from specified path 
cam = cv2.VideoCapture("/content/drive/MyDrive/major_project_cv/animation144p_input.mp4") 
fps = cam.get(cv2.CAP_PROP_FPS)
print(fps)


try:
      
    # Creating a folder named data 
    if not os.path.exists('data'): 
        os.makedirs('data') 
  
# if not created then raise error 
except OSError:
    print ('Error: Creating directory of data') 
  
#frames Extraction from video 
currentframe = 0
arr_img = []
while(True): 
      
    # reading from frame 
    ret,frame = cam.read() 
  
    if ret: 
        # if video is still left continue creating images 
        name = '/content/drive/MyDrive/major_project_cv/data/frame/' + str(currentframe).zfill(3) + '.jpg'
        print ('Creating...' + name) 
  
        # writing the extracted images 
        cv2.imwrite(name, frame) 
  
        # increasing counter so that it will show how many frames are created 
        currentframe += 1
        #storing the path of extracted frames in a list
        arr_img.append(name)
    else: 
        break
# print(arr_img)

start = timeit.default_timer()



model = generator()
model.load_weights('/content/drive/MyDrive/major_project_cv/gan_generator.h5')


#Initialization of an empty list to store the super resolved images
arr_output=[]
print(len(arr_img))
n= len(arr_img)

#Implementation of SRGAN Model in extracted frames
for i in range(n):
    lr = load_image(arr_img[i])
    sr = resolve_single(model, lr)
    #plot_sample(lr, sr)
  
    arr_output.append(sr)
stop = timeit.default_timer()
#print(arr_output)

print("time : ", stop-start)

# Release all space and windows once done 
cam.release() 
cv2.destroyAllWindows()
# Out:
# 25.0
# Creating.../content/drive/MyDrive/major_project_cv/data/frame/000.jpg
# Creating.../content/drive/MyDrive/major_project_cv/data/frame/001.jpg
# Creating.../content/drive/MyDrive/major_project_cv/data/frame/002.jpg
# Creating.../content/drive/MyDrive/major_project_cv/data/frame/003.jpg
# Creating.../content/drive/MyDrive/major_project_cv/data/frame/004.jpg
# Creating.../content/drive/MyDrive/major_project_cv/data/frame/005.jpg
# Creating.../content/drive/MyDrive/major_project_cv/data/frame/006.jpg
# Creating.../content/drive/MyDrive/major_project_cv/data/frame/007.jpg
# Creating.../content/drive/MyDrive/major_project_cv/data/frame/008.jpg
# Creating.../content/drive/MyDrive/major_project_cv/data/frame/009.jpg
# Creating.../content/drive/MyDrive/major_project_cv/data/frame/010.jpg
# Creating.../content/drive/MyDrive/major_project_cv/data/frame/011.jpg
# Creating.../content/drive/MyDrive/major_project_cv/data/frame/012.jpg
# Creating.../content/drive/MyDrive/major_project_cv/data/frame/013.jpg
# Creating.../content/drive/MyDrive/major_project_cv/data/frame/014.jpg
# Creating.../content/drive/MyDrive/major_project_cv/data/frame/015.jpg
# Creating.../content/drive/MyDrive/major_project_cv/data/frame/016.jpg
# Creating.../content/drive/MyDrive/major_project_cv/data/frame/017.jpg
# Creating.../content/drive/MyDrive/major_project_cv/data/frame/018.jpg
# Creating.../content/drive/MyDrive/major_project_cv/data/frame/019.jpg
# Creating.../content/drive/MyDrive/major_project_cv/data/frame/020.jpg
# Creating.../content/drive/MyDrive/major_project_cv/data/frame/021.jpg
# Creating.../content/drive/MyDrive/major_project_cv/data/frame/022.jpg
# Creating.../content/drive/MyDrive/major_project_cv/data/frame/023.jpg
# Creating.../content/drive/MyDrive/major_project_cv/data/frame/024.jpg
# Creating.../content/drive/MyDrive/major_project_cv/data/frame/025.jpg
# Creating.../content/drive/MyDrive/major_project_cv/data/frame/026.jpg
# Creating.../content/drive/MyDrive/major_project_cv/data/frame/027.jpg
# Creating.../content/drive/MyDrive/major_project_cv/data/frame/028.jpg
# Creating.../content/drive/MyDrive/major_project_cv/data/frame/029.jpg
# Creating.../content/drive/MyDrive/major_project_cv/data/frame/030.jpg
# Creating.../content/drive/MyDrive/major_project_cv/data/frame/031.jpg
# Creating.../content/drive/MyDrive/major_project_cv/data/frame/032.jpg
# Creating.../content/drive/MyDrive/major_project_cv/data/frame/033.jpg
# Creating.../content/drive/MyDrive/major_project_cv/data/frame/034.jpg
# Creating.../content/drive/MyDrive/major_project_cv/data/frame/035.jpg
# Creating.../content/drive/MyDrive/major_project_cv/data/frame/036.jpg
# Creating.../content/drive/MyDrive/major_project_cv/data/frame/037.jpg
# Creating.../content/drive/MyDrive/major_project_cv/data/frame/038.jpg
# Creating.../content/drive/MyDrive/major_project_cv/data/frame/039.jpg
# Creating.../content/drive/MyDrive/major_project_cv/data/frame/040.jpg
# Creating.../content/drive/MyDrive/major_project_cv/data/frame/041.jpg
# Creating.../content/drive/MyDrive/major_project_cv/data/frame/042.jpg
# Creating.../content/drive/MyDrive/major_project_cv/data/frame/043.jpg
# Creating.../content/drive/MyDrive/major_project_cv/data/frame/044.jpg
# Creating.../content/drive/MyDrive/major_project_cv/data/frame/045.jpg
# Creating.../content/drive/MyDrive/major_project_cv/data/frame/046.jpg
# Creating.../content/drive/MyDrive/major_project_cv/data/frame/047.jpg
# Creating.../content/drive/MyDrive/major_project_cv/data/frame/048.jpg
# Creating.../content/drive/MyDrive/major_project_cv/data/frame/049.jpg
# Creating.../content/drive/MyDrive/major_project_cv/data/frame/050.jpg
# Creating.../content/drive/MyDrive/major_project_cv/data/frame/051.jpg
# Creating.../content/drive/MyDrive/major_project_cv/data/frame/052.jpg
# Creating.../content/drive/MyDrive/major_project_cv/data/frame/053.jpg
# Creating.../content/drive/MyDrive/major_project_cv/data/frame/054.jpg
# Creating.../content/drive/MyDrive/major_project_cv/data/frame/055.jpg
# Creating.../content/drive/MyDrive/major_project_cv/data/frame/056.jpg
# Creating.../content/drive/MyDrive/major_project_cv/data/frame/057.jpg
# Creating.../content/drive/MyDrive/major_project_cv/data/frame/058.jpg
# Creating.../content/drive/MyDrive/major_project_cv/data/frame/059.jpg
# Creating.../content/drive/MyDrive/major_project_cv/data/frame/060.jpg
# Creating.../content/drive/MyDrive/major_project_cv/data/frame/061.jpg
# Creating.../content/drive/MyDrive/major_project_cv/data/frame/062.jpg
# Creating.../content/drive/MyDrive/major_project_cv/data/frame/063.jpg
# Creating.../content/drive/MyDrive/major_project_cv/data/frame/064.jpg
# Creating.../content/drive/MyDrive/major_project_cv/data/frame/065.jpg
# Creating.../content/drive/MyDrive/major_project_cv/data/frame/066.jpg
# Creating.../content/drive/MyDrive/major_project_cv/data/frame/067.jpg
# Creating.../content/drive/MyDrive/major_project_cv/data/frame/068.jpg
# Creating.../content/drive/MyDrive/major_project_cv/data/frame/069.jpg
# Creating.../content/drive/MyDrive/major_project_cv/data/frame/070.jpg
# Creating.../content/drive/MyDrive/major_project_cv/data/frame/071.jpg
# Creating.../content/drive/MyDrive/major_project_cv/data/frame/072.jpg
# Creating.../content/drive/MyDrive/major_project_cv/data/frame/073.jpg
# Creating.../content/drive/MyDrive/major_project_cv/data/frame/074.jpg
# Creating.../content/drive/MyDrive/major_project_cv/data/frame/075.jpg
# Creating.../content/drive/MyDrive/major_project_cv/data/frame/076.jpg
# Creating.../content/drive/MyDrive/major_project_cv/data/frame/077.jpg
# Creating.../content/drive/MyDrive/major_project_cv/data/frame/078.jpg
# Creating.../content/drive/MyDrive/major_project_cv/data/frame/079.jpg
# Creating.../content/drive/MyDrive/major_project_cv/data/frame/080.jpg
# Creating.../content/drive/MyDrive/major_project_cv/data/frame/081.jpg
# Creating.../content/drive/MyDrive/major_project_cv/data/frame/082.jpg
# Creating.../content/drive/MyDrive/major_project_cv/data/frame/083.jpg
# Creating.../content/drive/MyDrive/major_project_cv/data/frame/084.jpg
# Creating.../content/drive/MyDrive/major_project_cv/data/frame/085.jpg
# Creating.../content/drive/MyDrive/major_project_cv/data/frame/086.jpg
# Creating.../content/drive/MyDrive/major_project_cv/data/frame/087.jpg
# Creating.../content/drive/MyDrive/major_project_cv/data/frame/088.jpg
# Creating.../content/drive/MyDrive/major_project_cv/data/frame/089.jpg
# Creating.../content/drive/MyDrive/major_project_cv/data/frame/090.jpg
# Creating.../content/drive/MyDrive/major_project_cv/data/frame/091.jpg
# Creating.../content/drive/MyDrive/major_project_cv/data/frame/092.jpg
# Creating.../content/drive/MyDrive/major_project_cv/data/frame/093.jpg
# Creating.../content/drive/MyDrive/major_project_cv/data/frame/094.jpg
# Creating.../content/drive/MyDrive/major_project_cv/data/frame/095.jpg
# Creating.../content/drive/MyDrive/major_project_cv/data/frame/096.jpg
# Creating.../content/drive/MyDrive/major_project_cv/data/frame/097.jpg
# Creating.../content/drive/MyDrive/major_project_cv/data/frame/098.jpg
# Creating.../content/drive/MyDrive/major_project_cv/data/frame/099.jpg
# Creating.../content/drive/MyDrive/major_project_cv/data/frame/100.jpg
# Creating.../content/drive/MyDrive/major_project_cv/data/frame/101.jpg
# Creating.../content/drive/MyDrive/major_project_cv/data/frame/102.jpg
# Creating.../content/drive/MyDrive/major_project_cv/data/frame/103.jpg
# Creating.../content/drive/MyDrive/major_project_cv/data/frame/104.jpg
# Creating.../content/drive/MyDrive/major_project_cv/data/frame/105.jpg
# Creating.../content/drive/MyDrive/major_project_cv/data/frame/106.jpg
# Creating.../content/drive/MyDrive/major_project_cv/data/frame/107.jpg
# Creating.../content/drive/MyDrive/major_project_cv/data/frame/108.jpg
# Creating.../content/drive/MyDrive/major_project_cv/data/frame/109.jpg
# Creating.../content/drive/MyDrive/major_project_cv/data/frame/110.jpg
# Creating.../content/drive/MyDrive/major_project_cv/data/frame/111.jpg
# Creating.../content/drive/MyDrive/major_project_cv/data/frame/112.jpg
# Creating.../content/drive/MyDrive/major_project_cv/data/frame/113.jpg
# Creating.../content/drive/MyDrive/major_project_cv/data/frame/114.jpg
# Creating.../content/drive/MyDrive/major_project_cv/data/frame/115.jpg
# Creating.../content/drive/MyDrive/major_project_cv/data/frame/116.jpg
# Creating.../content/drive/MyDrive/major_project_cv/data/frame/117.jpg
# Creating.../content/drive/MyDrive/major_project_cv/data/frame/118.jpg
# Creating.../content/drive/MyDrive/major_project_cv/data/frame/119.jpg
# Creating.../content/drive/MyDrive/major_project_cv/data/frame/120.jpg
# Creating.../content/drive/MyDrive/major_project_cv/data/frame/121.jpg
# Creating.../content/drive/MyDrive/major_project_cv/data/frame/122.jpg
# Creating.../content/drive/MyDrive/major_project_cv/data/frame/123.jpg
# Creating.../content/drive/MyDrive/major_project_cv/data/frame/124.jpg
# Creating.../content/drive/MyDrive/major_project_cv/data/frame/125.jpg
# Creating.../content/drive/MyDrive/major_project_cv/data/frame/126.jpg
# Creating.../content/drive/MyDrive/major_project_cv/data/frame/127.jpg
# Creating.../content/drive/MyDrive/major_project_cv/data/frame/128.jpg
# Creating.../content/drive/MyDrive/major_project_cv/data/frame/129.jpg
# Creating.../content/drive/MyDrive/major_project_cv/data/frame/130.jpg
# Creating.../content/drive/MyDrive/major_project_cv/data/frame/131.jpg
# Creating.../content/drive/MyDrive/major_project_cv/data/frame/132.jpg
# Creating.../content/drive/MyDrive/major_project_cv/data/frame/133.jpg
# Creating.../content/drive/MyDrive/major_project_cv/data/frame/134.jpg
# Creating.../content/drive/MyDrive/major_project_cv/data/frame/135.jpg
# Creating.../content/drive/MyDrive/major_project_cv/data/frame/136.jpg
# Creating.../content/drive/MyDrive/major_project_cv/data/frame/137.jpg
# Creating.../content/drive/MyDrive/major_project_cv/data/frame/138.jpg
# Creating.../content/drive/MyDrive/major_project_cv/data/frame/139.jpg
# Creating.../content/drive/MyDrive/major_project_cv/data/frame/140.jpg
# Creating.../content/drive/MyDrive/major_project_cv/data/frame/141.jpg
# Creating.../content/drive/MyDrive/major_project_cv/data/frame/142.jpg
# Creating.../content/drive/MyDrive/major_project_cv/data/frame/143.jpg
# Creating.../content/drive/MyDrive/major_project_cv/data/frame/144.jpg
# Creating.../content/drive/MyDrive/major_project_cv/data/frame/145.jpg
# Creating.../content/drive/MyDrive/major_project_cv/data/frame/146.jpg
# Creating.../content/drive/MyDrive/major_project_cv/data/frame/147.jpg
# Creating.../content/drive/MyDrive/major_project_cv/data/frame/148.jpg
# Creating.../content/drive/MyDrive/major_project_cv/data/frame/149.jpg
# Creating.../content/drive/MyDrive/major_project_cv/data/frame/150.jpg
# Creating.../content/drive/MyDrive/major_project_cv/data/frame/151.jpg
# Creating.../content/drive/MyDrive/major_project_cv/data/frame/152.jpg
# Creating.../content/drive/MyDrive/major_project_cv/data/frame/153.jpg
# Creating.../content/drive/MyDrive/major_project_cv/data/frame/154.jpg
# Creating.../content/drive/MyDrive/major_project_cv/data/frame/155.jpg
# Creating.../content/drive/MyDrive/major_project_cv/data/frame/156.jpg
# Creating.../content/drive/MyDrive/major_project_cv/data/frame/157.jpg
# Creating.../content/drive/MyDrive/major_project_cv/data/frame/158.jpg
# Creating.../content/drive/MyDrive/major_project_cv/data/frame/159.jpg
# Creating.../content/drive/MyDrive/major_project_cv/data/frame/160.jpg
# Creating.../content/drive/MyDrive/major_project_cv/data/frame/161.jpg
# Creating.../content/drive/MyDrive/major_project_cv/data/frame/162.jpg
# Creating.../content/drive/MyDrive/major_project_cv/data/frame/163.jpg
# Creating.../content/drive/MyDrive/major_project_cv/data/frame/164.jpg
# Creating.../content/drive/MyDrive/major_project_cv/data/frame/165.jpg
# Creating.../content/drive/MyDrive/major_project_cv/data/frame/166.jpg
# Creating.../content/drive/MyDrive/major_project_cv/data/frame/167.jpg
# Creating.../content/drive/MyDrive/major_project_cv/data/frame/168.jpg
# Creating.../content/drive/MyDrive/major_project_cv/data/frame/169.jpg
# Creating.../content/drive/MyDrive/major_project_cv/data/frame/170.jpg
# Creating.../content/drive/MyDrive/major_project_cv/data/frame/171.jpg
# Creating.../content/drive/MyDrive/major_project_cv/data/frame/172.jpg
# Creating.../content/drive/MyDrive/major_project_cv/data/frame/173.jpg
# Creating.../content/drive/MyDrive/major_project_cv/data/frame/174.jpg
# Creating.../content/drive/MyDrive/major_project_cv/data/frame/175.jpg
# Creating.../content/drive/MyDrive/major_project_cv/data/frame/176.jpg
# Creating.../content/drive/MyDrive/major_project_cv/data/frame/177.jpg
# Creating.../content/drive/MyDrive/major_project_cv/data/frame/178.jpg
# Creating.../content/drive/MyDrive/major_project_cv/data/frame/179.jpg
# Creating.../content/drive/MyDrive/major_project_cv/data/frame/180.jpg
# Creating.../content/drive/MyDrive/major_project_cv/data/frame/181.jpg
# Creating.../content/drive/MyDrive/major_project_cv/data/frame/182.jpg
# Creating.../content/drive/MyDrive/major_project_cv/data/frame/183.jpg
# Creating.../content/drive/MyDrive/major_project_cv/data/frame/184.jpg
# Creating.../content/drive/MyDrive/major_project_cv/data/frame/185.jpg
# Creating.../content/drive/MyDrive/major_project_cv/data/frame/186.jpg
# Creating.../content/drive/MyDrive/major_project_cv/data/frame/187.jpg
# Creating.../content/drive/MyDrive/major_project_cv/data/frame/188.jpg
# Creating.../content/drive/MyDrive/major_project_cv/data/frame/189.jpg
# Creating.../content/drive/MyDrive/major_project_cv/data/frame/190.jpg
# Creating.../content/drive/MyDrive/major_project_cv/data/frame/191.jpg
# Creating.../content/drive/MyDrive/major_project_cv/data/frame/192.jpg
# Creating.../content/drive/MyDrive/major_project_cv/data/frame/193.jpg
# Creating.../content/drive/MyDrive/major_project_cv/data/frame/194.jpg
# Creating.../content/drive/MyDrive/major_project_cv/data/frame/195.jpg
# Creating.../content/drive/MyDrive/major_project_cv/data/frame/196.jpg
# Creating.../content/drive/MyDrive/major_project_cv/data/frame/197.jpg
# Creating.../content/drive/MyDrive/major_project_cv/data/frame/198.jpg
# Creating.../content/drive/MyDrive/major_project_cv/data/frame/199.jpg
# Creating.../content/drive/MyDrive/major_project_cv/data/frame/200.jpg
# Creating.../content/drive/MyDrive/major_project_cv/data/frame/201.jpg
# Creating.../content/drive/MyDrive/major_project_cv/data/frame/202.jpg
# Creating.../content/drive/MyDrive/major_project_cv/data/frame/203.jpg
# Creating.../content/drive/MyDrive/major_project_cv/data/frame/204.jpg
# Creating.../content/drive/MyDrive/major_project_cv/data/frame/205.jpg
# Creating.../content/drive/MyDrive/major_project_cv/data/frame/206.jpg
# Creating.../content/drive/MyDrive/major_project_cv/data/frame/207.jpg
# Creating.../content/drive/MyDrive/major_project_cv/data/frame/208.jpg
# Creating.../content/drive/MyDrive/major_project_cv/data/frame/209.jpg
# Creating.../content/drive/MyDrive/major_project_cv/data/frame/210.jpg
# Creating.../content/drive/MyDrive/major_project_cv/data/frame/211.jpg
# Creating.../content/drive/MyDrive/major_project_cv/data/frame/212.jpg
# Creating.../content/drive/MyDrive/major_project_cv/data/frame/213.jpg
# Creating.../content/drive/MyDrive/major_project_cv/data/frame/214.jpg
# Creating.../content/drive/MyDrive/major_project_cv/data/frame/215.jpg
# Creating.../content/drive/MyDrive/major_project_cv/data/frame/216.jpg
# Creating.../content/drive/MyDrive/major_project_cv/data/frame/217.jpg
# Creating.../content/drive/MyDrive/major_project_cv/data/frame/218.jpg
# Creating.../content/drive/MyDrive/major_project_cv/data/frame/219.jpg
# Creating.../content/drive/MyDrive/major_project_cv/data/frame/220.jpg
# Creating.../content/drive/MyDrive/major_project_cv/data/frame/221.jpg
# Creating.../content/drive/MyDrive/major_project_cv/data/frame/222.jpg
# Creating.../content/drive/MyDrive/major_project_cv/data/frame/223.jpg
# Creating.../content/drive/MyDrive/major_project_cv/data/frame/224.jpg
# Creating.../content/drive/MyDrive/major_project_cv/data/frame/225.jpg
# Creating.../content/drive/MyDrive/major_project_cv/data/frame/226.jpg
# Creating.../content/drive/MyDrive/major_project_cv/data/frame/227.jpg
# Creating.../content/drive/MyDrive/major_project_cv/data/frame/228.jpg
# Creating.../content/drive/MyDrive/major_project_cv/data/frame/229.jpg
# Creating.../content/drive/MyDrive/major_project_cv/data/frame/230.jpg
# Creating.../content/drive/MyDrive/major_project_cv/data/frame/231.jpg
# Creating.../content/drive/MyDrive/major_project_cv/data/frame/232.jpg
# Creating.../content/drive/MyDrive/major_project_cv/data/frame/233.jpg
# Creating.../content/drive/MyDrive/major_project_cv/data/frame/234.jpg
# Creating.../content/drive/MyDrive/major_project_cv/data/frame/235.jpg
# Creating.../content/drive/MyDrive/major_project_cv/data/frame/236.jpg
# Creating.../content/drive/MyDrive/major_project_cv/data/frame/237.jpg
# Creating.../content/drive/MyDrive/major_project_cv/data/frame/238.jpg
# Creating.../content/drive/MyDrive/major_project_cv/data/frame/239.jpg
# Creating.../content/drive/MyDrive/major_project_cv/data/frame/240.jpg
# Creating.../content/drive/MyDrive/major_project_cv/data/frame/241.jpg
# Creating.../content/drive/MyDrive/major_project_cv/data/frame/242.jpg
# Creating.../content/drive/MyDrive/major_project_cv/data/frame/243.jpg
# Creating.../content/drive/MyDrive/major_project_cv/data/frame/244.jpg
# Creating.../content/drive/MyDrive/major_project_cv/data/frame/245.jpg
# Creating.../content/drive/MyDrive/major_project_cv/data/frame/246.jpg
# Creating.../content/drive/MyDrive/major_project_cv/data/frame/247.jpg
# Creating.../content/drive/MyDrive/major_project_cv/data/frame/248.jpg
# Creating.../content/drive/MyDrive/major_project_cv/data/frame/249.jpg
# Creating.../content/drive/MyDrive/major_project_cv/data/frame/250.jpg
# Creating.../content/drive/MyDrive/major_project_cv/data/frame/251.jpg
# 252
# time :  32.300294466000196

# %%
import os
#Importing necessary libraries
from keras.preprocessing.image import load_img
from keras.preprocessing.image import img_to_array
from keras.preprocessing.image import array_to_img
from keras.preprocessing.image import save_img

#Making a directory for storing super resolved frames in image format
#os.makedirs("output_images")

#Initialization of an empty list to store the path of Super resolved frames
s_res= []
for j in range(len(arr_output)):
  out_name = '/content/drive/MyDrive/major_project_cv/output_images/frame/' + str(j).zfill(3) + '.jpg'
  img_pil = array_to_img(arr_output[j])
  img1 = save_img(out_name, img_pil)
  s_res.append(out_name)
  
#print(s_res)
# Out:
# Using TensorFlow backend.

# %%
import cv2
import numpy as np
for i in range(len(s_res)):
    filename=s_res[i]
    #reading each files
    img = cv2.imread(filename)
    height, width, layers = img.shape
    size = (width,height)

fps = 20       #Put the fps value as your convenience or 
               #Calculate by using (No. of frames)/Video_duration in seconds  

#Creation of output video               
out = cv2.VideoWriter('/content/drive/MyDrive/major_project_cv/output_vedio.mp4',cv2.VideoWriter_fourcc(*'DIVX'), fps , size)

#Writing Frames into video
for i in range(len(s_res)):
    out.write(cv2.imread(s_res[i]))
out.release()
